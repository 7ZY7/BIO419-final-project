# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
df=pd.read_excel('Data.xlsx')

# %%
df
# Out:
#                 State Victim Sex  Year
# 0              Alaska       Male  1980
# 1              Alaska       Male  1980
# 2              Alaska     Female  1980
# 3              Alaska       Male  1980
# 4              Alaska     Female  1980
# 5              Alaska       Male  1980
# 6              Alaska     Female  1980
# 7              Alaska     Female  1980
# 8              Alaska       Male  1980
# 9              Alaska       Male  1980
# 10             Alaska       Male  1980
# 11             Alaska       Male  1980
# 12             Alaska     Female  1980
# 13             Alaska       Male  1980
# 14             Alaska       Male  1980
# 15             Alaska       Male  1980
# 16             Alaska       Male  1980
# 17             Alaska       Male  1980
# 18             Alaska       Male  1980
# 19             Alaska       Male  1980
# 20             Alaska     Female  1980
# 21             Alaska       Male  1980
# 22             Alaska       Male  1980
# ...

# %%
ds=df.groupby(['State','Victim Sex','Year'])
dm=ds.size()
dm
# Out:
# State    Victim Sex  Year
# Alabama  Female      1980    131
#                      1981    102
#                      1982     90
#                      1983     85
#                      1984     96
#                      1985     93
#                      1986     94
#                      1987     84
#                      1988     90
#                      1989     98
#                      1990    114
#                      1991    108
#                      1992     76
#                      1993    117
#                      1994    113
#                      1995     98
#                      1996     87
#                      1997     95
#                      1998     77
#                      1999      3
#                      2000     57
#                      2001     88
#                      2002     68
#                      2003     70
#                      2004     57
#                      2005     68
#                      2006     77
# ...
